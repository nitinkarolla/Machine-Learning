# %%
import numpy as np
import pandas as pd
import seaborn as sns
import pyreadstat
import seaborn as sns

# %%
df, meta = pyreadstat.read_sav("E:\Semester-2\ML\Machine-Learning\Project\Data\ML1\Datasets\Data\CleanedDataset.sav")

# %%
df
# Out:
#       session_id        session_date last_update_date  \
# 0      2400853.0 2013-08-28 12:15:55    8/28/13 12:15
# 1      2400856.0 2013-08-28 12:13:49    8/28/13 12:13
# 2      2400860.0 2013-08-28 12:15:57    8/28/13 12:15
# 3      2400868.0 2013-08-28 12:12:21    8/28/13 12:12
# 4      2400872.0 2013-08-28 12:11:58    8/28/13 12:11
# 5      2400914.0 2013-08-28 12:19:46    8/28/13 12:19
# 6      2400916.0 2013-08-28 12:19:14    8/28/13 12:19
# 7      2400925.0 2013-08-28 12:16:21    8/28/13 12:16
# 8      2400934.0 2013-08-28 12:22:38    8/28/13 12:22
# 9      2407192.0 2013-09-03 10:42:30     9/3/13 10:42
# 10     2407222.0 2013-09-03 11:13:58     9/3/13 11:13
# 11     2407225.0 2013-09-03 11:16:17     9/3/13 11:16
# 12     2407227.0 2013-09-03 11:15:06     9/3/13 11:15
# 13     2407268.0 2013-09-03 11:36:06     9/3/13 11:36
# 14     2407271.0 2013-09-03 11:35:38     9/3/13 11:35
# 15     2407288.0 2013-09-03 12:22:40     9/3/13 12:22
# ...

# %%
df.shape
# Out:
# (6344, 382)

# %%
df_missing = df.isna()

# %%
df_missing.sum().sort_values(ascending = False)
# Out:
# mturk.exclude                 6341
# anchoring3bmeter              5908
# anchoring1bkm                 5896
# anchoring1akm                 5857
# anchoring3ameter              5836
# mturk.Submitted.PaymentReq    5382
# mturk.exclude.null            5344
# mturk.non.US                  5344
# mturk.keep                    5344
# mturk.total.mini.exps         5344
# mturk.duplicate               5344
# task_creation_date.45         4000
# anchoring2a                   3758
# anchoring1a                   3744
# anchoring4a                   3668
# anchoring2b                   3646
# anchoring1b                   3582
# anchoring3b                   3580
# scalesrecb                    3524
# scalesb                       3524
# anchoring3a                   3481
# anchoring4b                   3411
# gamblerfallacyb               3379
# gamblerfallacya               3367
# moneygenderb                  3291
# moneyageb                     3285
# reciprocityotherb             3270
# ...

# %%
df_dot = df == '.'

# %%
df_dot.sum().sort_values(ascending = False)
# Out:
# imptaskto               5508
# nativelang2             5455
# moneyethnicitya         3160
# moneyethnicityb         3048
# expcomments             2157
# exprunafter2            1831
# beginlocaltime          1329
# citizenship2             506
# imagineddescribe         254
# numparticipants          243
# ethnicity                242
# expgender                 51
# exprace                   51
# separatedornot            50
# race                      30
# nativelang                28
# priorexposure8            20
# priorexposure11           18
# priorexposure4            18
# priorexposure10           17
# exprunafter               17
# compensation              16
# priorexposure6            16
# citizenship               16
# priorexposure13           16
# priorexposure12           16
# priorexposure7            16
# priorexposure5            15
# priorexposure9            14
# recruitment               13
#                         ...
# task_url.44                0
# ...
